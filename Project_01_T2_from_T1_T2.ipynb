# %%
# Project_01
# Create T2 from paired T1_T2 image set

# %%
# Standard libraries - glob,  os, 

from glob import glob
import os
import random
import sys

# %%
import nibabel as nib
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
import numpy as np
import pandas as pd
import SimpleITK as sitk
from matplotlib import pyplot as plt
from scipy.ndimage.interpolation import map_coordinates
from scipy.ndimage.filters import gaussian_filter
from scipy import ndimage
import math
from skimage.filters import threshold_mean
from scipy.ndimage.interpolation import map_coordinates
from scipy.ndimage.filters import gaussian_filter
from scipy import ndimage
import cv2
import math

# %%
# Use magic function to display matplotlib plots within the notebook next to the code
# %matplotlib inline

# %%
# Define directories and sample the image
#
train_dir ='C:/Users/sathe/Medical_Image_Projects/Project_01/Data_T1_T2'
t1_dir = os.path.join(train_dir, 't1')
t2_dir = os.path.join(train_dir, 't2')

image_t1 = nib.load(t1_dir+'/IXI102-HH-1416-T1_fcm.nii.gz')
image_data_t1 = image_t1.get_fdata()
image_t2 = nib.load(t2_dir+'/IXI102-HH-1416-T2_reg_fcm.nii.gz')
image_data_t2 = image_t2.get_fdata()

# %%
# get the image size
img_shape_t1=image_data_t1.shape
img_shape_t1
# Out:
# (120, 120, 90)

# %%
img_shape_t2=image_data_t2.shape
img_shape_t2
# Out:
# (120, 120, 90)

# %%
plt.imshow(image_data_t1[:,:,45],cmap = 'gray')

# %%
plt.imshow(image_data_t2[:,:,45],cmap = 'gray')
